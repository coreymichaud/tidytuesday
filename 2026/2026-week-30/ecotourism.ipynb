# %% [markdown]
# # Ecotourism

# %%
# Libraries
import pydytuesday

# %%
# Get & import data
pydytuesday.get_week(2026, 30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Get & import data
# ----> 2 pydytuesday.get_week(2026, 30)
#
# NameError: name 'pydytuesday' is not defined
